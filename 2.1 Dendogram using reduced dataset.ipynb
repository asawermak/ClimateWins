# %% [markdown]
# # 2.1 Dendrograms using reduced dataset

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# [01. Import libraries](#01.-Import-libraries)

# %% [markdown]
# [02. Import Data](#02.-Import-Data)

# %% [markdown]
# [03. Create Dendrogram with Reduced Dataset](#03.-Create-Dendrogram-with-Reduced-Dataset)

# %% [markdown]
# ## 01. Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import operator
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from matplotlib.pyplot import figure

from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# %% [markdown]
# ## 02. Import Data

# %%
df_reduced= pd.read_csv(r'E:\Careerfoundry course\Careerfoundry Course Old\Machine Learning with Python\Gnerated Data\1990_PCA.csv')

# %%
df_reduced
# Out:
#      Unnamed: 0       PCA1      PCA2      PCA3      PCA4      PCA5      PCA6  \
# 0             0 -12.169671 -4.685677  0.154928 -1.084853  0.280123 -2.146968
# 1             1 -12.419740 -4.472289 -0.439003 -1.815241  0.057093 -1.609578
# 2             2 -12.476184 -3.721491 -0.447821 -1.481022 -0.363836 -1.817861
# 3             3 -11.368815 -6.627530  1.661990  0.094270 -0.684330 -0.449609
# 4             4 -11.134477 -5.643579  2.326510 -1.903502  1.438724 -0.937043
# ..          ...        ...       ...       ...       ...       ...       ...
# 360         360  -9.726748  4.176078  0.639312  1.841581 -4.095500  0.507952
# 361         361  -9.681677 -0.689732  2.740895  3.780138 -0.945148 -0.451839
# 362         362 -11.062835  4.505575  5.891185  1.690717 -0.605604 -0.002473
# 363         363  -7.489238 -1.216608  1.137483  1.241899 -1.934381 -0.753052
# 364         364 -10.305884 -0.176098  0.175115  0.047789  1.620401 -1.632264
#
#          PCA7      PCA8      PCA9     PCA10     PCA11
# 0    3.023177  2.624609  3.123887  0.553206  0.096518
# 1    2.748219  2.122121  1.859526  0.716231  0.759448
# 2    1.656831  0.628420  2.041449 -0.373988 -0.184283
# 3    0.757427  0.185194  0.567626  0.933576  0.582543
# 4    0.737243 -2.618016  1.700231 -0.635032 -1.107421
# ..        ...       ...       ...       ...       ...
# 360 -0.074996  1.201999 -1.923696 -2.116156 -0.032916
# 361  0.251685  2.845837 -0.463216  0.341435 -0.090889
# 362 -1.254015  1.978435  2.442610 -1.772573 -2.570720
# 363  2.076890 -1.919094  0.604127 -3.764997 -0.789584
# 364  2.174720  0.180863  0.646307 -2.175219 -1.131625
#
# [365 rows x 12 columns]

# %%
df_reduced = df_reduced.drop(columns =['Unnamed: 0'])

# %%
df_reduced
# Out:
#           PCA1      PCA2      PCA3      PCA4      PCA5      PCA6      PCA7  \
# 0   -12.169671 -4.685677  0.154928 -1.084853  0.280123 -2.146968  3.023177
# 1   -12.419740 -4.472289 -0.439003 -1.815241  0.057093 -1.609578  2.748219
# 2   -12.476184 -3.721491 -0.447821 -1.481022 -0.363836 -1.817861  1.656831
# 3   -11.368815 -6.627530  1.661990  0.094270 -0.684330 -0.449609  0.757427
# 4   -11.134477 -5.643579  2.326510 -1.903502  1.438724 -0.937043  0.737243
# ..         ...       ...       ...       ...       ...       ...       ...
# 360  -9.726748  4.176078  0.639312  1.841581 -4.095500  0.507952 -0.074996
# 361  -9.681677 -0.689732  2.740895  3.780138 -0.945148 -0.451839  0.251685
# 362 -11.062835  4.505575  5.891185  1.690717 -0.605604 -0.002473 -1.254015
# 363  -7.489238 -1.216608  1.137483  1.241899 -1.934381 -0.753052  2.076890
# 364 -10.305884 -0.176098  0.175115  0.047789  1.620401 -1.632264  2.174720
#
#          PCA8      PCA9     PCA10     PCA11
# 0    2.624609  3.123887  0.553206  0.096518
# 1    2.122121  1.859526  0.716231  0.759448
# 2    0.628420  2.041449 -0.373988 -0.184283
# 3    0.185194  0.567626  0.933576  0.582543
# 4   -2.618016  1.700231 -0.635032 -1.107421
# ..        ...       ...       ...       ...
# 360  1.201999 -1.923696 -2.116156 -0.032916
# 361  2.845837 -0.463216  0.341435 -0.090889
# 362  1.978435  2.442610 -1.772573 -2.570720
# 363 -1.919094  0.604127 -3.764997 -0.789584
# 364  0.180863  0.646307 -2.175219 -1.131625
#
# [365 rows x 11 columns]

# %% [markdown]
# ## 03. Create Dendrogram with Reduced Dataset

# %%
distance_single = linkage(df_reduced.loc[:,
['PCA1',
'PCA2',
'PCA3',
'PCA4',
'PCA5',
'PCA6',
'PCA7',
'PCA8',
'PCA9',
'PCA10',
'PCA11']],method="single")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Single Method",fontsize=18)
plt.show()

# %%
distance_single = linkage(df_reduced.loc[:,
['PCA1',
'PCA2',
'PCA3',
'PCA4',
'PCA5',
'PCA6',
'PCA7',
'PCA8',
'PCA9',
'PCA10',
'PCA11',]],method="complete")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Complete Method",fontsize=18)
plt.show()

# %%
distance_single = linkage(df_reduced.loc[:,
['PCA1',
'PCA2',
'PCA3',
'PCA4',
'PCA5',
'PCA6',
'PCA7',
'PCA8',
'PCA9',
'PCA10',
'PCA11',]],method="average")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Average Method",fontsize=18)
plt.show()

# %%
distance_single = linkage(df_reduced.loc[:,
['PCA1',
'PCA2',
'PCA3',
'PCA4',
'PCA5',
'PCA6',
'PCA7',
'PCA8',
'PCA9',
'PCA10',
'PCA11',]],method="ward")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Ward Method",fontsize=18)
plt.show()
